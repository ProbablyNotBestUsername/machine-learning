# %%
import re
from pyppeteer import launch # type: ignore
from random import randint

import seaborn as sns
import matplotlib as plt

# %%
USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_7_10) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.0 Safari/605.1.15',
]
CAPTCHA_MARKER = "captcha"
LIST_ITEM = '[data-test-id="movie-list-item"]'

# %%
async def wait_captcha(page):
  print('🛑 Captcha shown')
  while CAPTCHA_MARKER in page.url:
    await page.waitForNavigation({'waitUntil': 'domcontentloaded'})
  # await page.waitForSelector(LIST_ITEM, timeout=0)
  print('✅ Captcha solved')

# %%
async def safe_goto(page, url):
  await page.goto(url, {'waitUntil': 'domcontentloaded'})
  if CAPTCHA_MARKER in page.url:
    await wait_captcha(page)
  # await page.waitForSelector(LIST_ITEM, timeout=0)

# %%
async def scrape_movie(page, page_number):
    url = f"https://www.kinopoisk.ru/lists/movies/top250/?page={page_number}"
    print(f"Scraping: {url}")
    await safe_goto(page, url)

    movie_elements = await page.querySelectorAll('[data-test-id="movie-list-item"]')

    movies_data = []
    for movie in movie_elements:
        href_elem = await movie.querySelector('.base-movie-main-info_link__K161e')
        href = await (await href_elem.getProperty('href')).jsonValue() if href_elem else 'None'
        movie_id = re.search(r'(\d{3,})', href).group(1) if href != None else 'None'


        title_elem = await movie.querySelector('[class^="styles_mainTitle__"]')
        title = await (await title_elem.getProperty('textContent')).jsonValue() if title_elem else 'None'
        title = title.strip()

        secondary_elem = await movie.querySelector('[class^="desktop-list-main-info_secondaryTitleSlot__"]')
        secondary_text = await (
            await secondary_elem.getProperty('textContent')).jsonValue() if secondary_elem else 'None'
        secondary_text = secondary_text.strip()

        match = re.search(r'\b(19|20)\d{2}\b', secondary_text)
        year = match.group(0) if match else 'None'

        rating_elem = await movie.querySelector('[class^="styles_kinopoiskValuePositive__"]')
        rating = await (await rating_elem.getProperty('textContent')).jsonValue() if rating_elem else 'None'
        rating = rating.strip()

        additional_info_elems = await movie.querySelectorAll('[class^="desktop-list-main-info_additionalInfo__"]')
        country = genre = director = None

        if additional_info_elems:
            text1 = await (await additional_info_elems[0].getProperty('textContent')).jsonValue()
            text1 = text1.strip()
            if "Режиссёр:" in text1:
                left, director_text = text1.split("Режиссёр:", 1)
                director = director_text.strip()
                if "•" in left:
                    country, genre = [part.strip() for part in left.split("•", 1)]
                else:
                    country = left.strip()
                    genre = None
            else:
                if "•" in text1:
                    country, genre = [part.strip() for part in text1.split("•", 1)]
                else:
                    country = text1.strip()
                    genre = None
        

        movies_data.append({
            'id': movie_id,
            'Название': title,
            'Год': year,
            'Рейтинг': rating,
            'Страна': country,
            'Жанр': genre,  
            'Режиссёр': director
        })

    return movies_data

# %%
async def getMovieVotes(browser, movieId):
    newPage = await browser.newPage()
    await newPage.setUserAgent(USER_AGENTS[randint(0, len(USER_AGENTS)-1)])
    await safe_goto(newPage, f"https://www.kinopoisk.ru/film/{movieId}/votes/")

    votes = []
    votes_elements = await newPage.querySelectorAll('tr.rating_item')
    for row in votes_elements:
        href_elem = await row.querySelector('.profile_name a[href^="/user/"]')
        href = await (await href_elem.getProperty('href')).jsonValue() if href_elem else None
        
        user_id = None
        if href:
            match = re.search(r'/user/(\d+)/', href)
            user_id = match.group(1) if match else None

        rating_elem = await row.querySelector('.comm-title table td')
        rating = await (await rating_elem.getProperty('textContent')).jsonValue() if rating_elem else None
        rating = rating.strip() if rating else None
        
        votes.append({
            'user_id': user_id,
            'rating': rating
        })
        
    await newPage.close()

    print(votes)
    return votes

# %%
async def getProfileVotes(browser, profileId):
    newPage = await browser.newPage()
    await newPage.setUserAgent(USER_AGENTS[randint(0, len(USER_AGENTS)-1)])
    await safe_goto(newPage, f"https://www.kinopoisk.ru/user/{profileId}/votes/list/vs/vote/perpage/10/#list")

    votes = []

    items = await newPage.querySelectorAll('.profileFilmsList .item')

    for item in items:
        href_elem = await item.querySelector('.nameRus a')
        href = await (await href_elem.getProperty('href')).jsonValue() if href_elem else None
        
        # Extract movie ID from href (handles both /film/ and /movie/ URLs)
        movie_id = None
        if href:
            match = re.search(r'/film/(\d+)/?', href)
            movie_id = match.group(1) if match else None
        
        vote_elem = await item.querySelector('.vote')
        rating = await (await vote_elem.getProperty('textContent')).jsonValue() if vote_elem else None
        rating = rating.strip() if rating else None
        
        if movie_id and rating:
            votes.append({
                'movie_id': movie_id,
                'rating': rating
            })

    await newPage.close()
    
    print(votes)
    return votes

# %%
async def scrapeOtherStuff(browser, movies):
    parsed_movie_ids = set(movie['id'] for movie in movies)
    
    for item in movies:
        movieVotes = await getMovieVotes(browser, item['id'])
        movieVotes = movieVotes[:5] # Limit for testing

        for movieVotesList in movieVotes:
            profileVotes = await getProfileVotes(browser, movieVotesList['user_id'])
            
            # Find new movies that need to be parsed
            new_movie_ids = []
            for profileVote in profileVotes:
                movie_id = profileVote['movie_id']
                if movie_id not in parsed_movie_ids:
                    new_movie_ids.append(movie_id)
                    parsed_movie_ids.add(movie_id)
            
            # Parse new movies
            if new_movie_ids:
                print(f"Found {len(new_movie_ids)} new movies to parse")
                for movie_id in new_movie_ids:
                    new_movie = await scrape_single_movie(browser, movie_id)
                    if new_movie:
                        movies.append(new_movie)
                        print(f"Parsed new movie: {new_movie['Название']}")

        movieUniqueIds = [movie['id'] for movie in movies]
        print(f"Total unique movies: {len(set(movieUniqueIds))}")

# %%
async def scrape_single_movie(browser, movie_id):
    try:
        newPage = await browser.newPage()
        await newPage.setUserAgent(USER_AGENTS[randint(0, len(USER_AGENTS)-1)])
        await safe_goto(newPage, f"https://www.kinopoisk.ru/film/{movie_id}/")
        
        # Extract movie information
        title_elem = await newPage.querySelector('[class^="styles_title__"]')
        title = await (await title_elem.getProperty('textContent')).jsonValue() if title_elem else 'None'

        # Extract year using data-test-id selector
        year_elem = await newPage.querySelector('div[data-test-id="year"] .styles_valueDark__jsGKY a')
        year = await (await year_elem.getProperty('textContent')).jsonValue() if year_elem else 'None'
        year = year.strip() if year != 'None' else 'None'
        
        # If year not found, try extracting from title format "Film (2000)"
        if year == 'None' and title and title != 'None':
            match = re.search(r'\((\d{4})\)$', title)
            year = match.group(1) if match else 'None'
            
        # Remove year from title to get clean movie name
        if title and title != 'None':
            title = re.sub(r'\s*\(\d{4}\)$', '', title).strip()
        
        # Get rating
        rating_elem = await newPage.querySelector('[class*="styles_ratingKpTop__"] [class*="styles_value__"]')
        rating = await (await rating_elem.getProperty('textContent')).jsonValue() if rating_elem else 'None'
        rating = rating.strip()
        
        # Get genre using data-test-id selector
        genre_elem = await newPage.querySelector('div[data-test-id="genres"] .styles_valueDark__jsGKY a')
        genre = await (await genre_elem.getProperty('textContent')).jsonValue() if genre_elem else 'None'
        genre = genre.strip() if genre != 'None' else 'None'
        
        # Get country using data-test-id selector
        country_elem = await newPage.querySelector('div[data-test-id="countries"] .styles_valueDark__jsGKY a')
        country = await (await country_elem.getProperty('textContent')).jsonValue() if country_elem else 'None'
        country = country.strip() if country != 'None' else 'None'
        
        # Get director using data-test-id selector
        director_elem = await newPage.querySelector('div[data-test-id="directors"] .styles_valueDark__jsGKY a')
        director = await (await director_elem.getProperty('textContent')).jsonValue() if director_elem else 'None'
        director = director.strip() if director != 'None' else 'None'
        
        await newPage.close()
        
        return {
            'id': movie_id,
            'Название': title,
            'Год': year,
            'Рейтинг': rating,
            'Страна': country,
            'Жанр': genre,
            'Режиссёр': director
        }
    except Exception as e:
        print(f"Error scraping movie {movie_id}: {e}")
        if 'newPage' in locals():
            await newPage.close()
        return None

# %%
async def scraper():
    browser = await launch({
        "headless": False,
        "executablePath": r"C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe",
        "args": ["--disable-blink-features=AutomationControlled"]
    })
    page = await browser.newPage()
    await page.setUserAgent(USER_AGENTS[randint(0, len(USER_AGENTS)-1)])

    all_movies = []
    for page_number in range(1, 2):
        movies_on_page = await scrape_movie(page, page_number)
        all_movies.extend(movies_on_page)

    all_movies = all_movies[:2]  # Limit for testing

    await scrapeOtherStuff(browser, all_movies)

    # newPage = await browser.newPage()
    # await newPage.setUserAgent(USER_AGENTS[randint(0, len(USER_AGENTS)-1)])
    # await getProfileVotes(newPage, 16195960)  # Example movie ID

    return
    
    all_movies = []
    for page_number in range(1, 6):
        movies_on_page = await scrape_movie(page, page_number)
        all_movies.extend(movies_on_page)

    await browser.close()

    df = pd.DataFrame(all_movies)
    df["id"] = df["id"].astype(int)
    df["Название"] = df["Название"].astype(str)
    df["Год"] = df["Год"].astype(int)
    df["Рейтинг"] = df["Рейтинг"].astype(float)
    df["Страна"] = df["Страна"].astype(str)
    df["Жанр"] = df["Жанр"].astype(str)
    df["Режиссёр"] = df["Режиссёр"].astype(str)

    df.to_csv("movies.csv", index=False, header=True)
    return df

# %%
movies = await scraper()
# Out:
# Scraping: https://www.kinopoisk.ru/lists/movies/top250/?page=1
# [{'user_id': '73414739', 'rating': '10'}, {'user_id': '35403457', 'rating': '9'}, {'user_id': '159391171', 'rating': '10'}, {'user_id': '198349381', 'rating': '10'}, {'user_id': '207545723', 'rating': '10'}, {'user_id': '40492414', 'rating': '8'}, {'user_id': '171426451', 'rating': '8'}, {'user_id': '96333201', 'rating': '8'}, {'user_id': '54103275', 'rating': '7'}, {'user_id': '72127065', 'rating': '10'}, {'user_id': '70768787', 'rating': '10'}, {'user_id': '199726760', 'rating': '10'}, {'user_id': '160912514', 'rating': '10'}, {'user_id': '207239672', 'rating': '10'}, {'user_id': '186316864', 'rating': '10'}, {'user_id': '200543940', 'rating': '10'}, {'user_id': '175864776', 'rating': '10'}, {'user_id': '144575965', 'rating': '10'}, {'user_id': '84803186', 'rating': '10'}, {'user_id': '16788099', 'rating': '10'}]
# [{'movie_id': '535341', 'rating': '10'}, {'movie_id': '5417693', 'rating': '5'}, {'movie_id': '6440213', 'rating': '7'}, {'movie_id': '5965493', 'rating': '4'}, {'movie_id': '6332966', 'rating': '4'}, {'movie_id': '5333364', 'rating': '7'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Финальный трейлер
# Parsed new movie: ТВ-ролик
# Parsed new movie: ТВ-ролик
# Parsed new movie: Трейлер
# [{'movie_id': '535341', 'rating': '9'}, {'movie_id': '1229683', 'rating': '6'}, {'movie_id': '437410', 'rating': '8'}, {'movie_id': '1347949', 'rating': '8'}, {'movie_id': '7088374', 'rating': '6'}, {'movie_id': '1047492', 'rating': '8'}, {'movie_id': '4826207', 'rating': '6'}, {'movie_id': '7229988', 'rating': '6'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Тизер-трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '535341', 'rating': '10'}, {'movie_id': '1047736', 'rating': '8'}, {'movie_id': '969760', 'rating': '10'}, {'movie_id': '1345717', 'rating': '10'}, {'movie_id': '1045449', 'rating': '10'}]
# Found 4 new movies to parse
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер (дублированный)
# [{'movie_id': '535341', 'rating': '10'}, {'movie_id': '102198', 'rating': '10'}, {'movie_id': '601564', 'rating': '10'}, {'movie_id': '5105855', 'rating': '10'}]
# Found 3 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '535341', 'rating': '10'}, {'movie_id': '7481222', 'rating': '7'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер №2
# Total unique movies: 22
# [{'user_id': '58005928', 'rating': '10'}, {'user_id': '210323244', 'rating': '10'}, {'user_id': '117169593', 'rating': '9'}, {'user_id': '4507446', 'rating': '10'}, {'user_id': '171409086', 'rating': '9'}, {'user_id': '32779018', 'rating': '10'}, {'user_id': '28324399', 'rating': '10'}, {'user_id': '106216731', 'rating': '10'}, {'user_id': '197116249', 'rating': '7'}, {'user_id': '20603574', 'rating': '8'}, {'user_id': '48712037', 'rating': '10'}, {'user_id': '124416796', 'rating': '10'}, {'user_id': '178738233', 'rating': '1'}, {'user_id': '55429623', 'rating': '10'}, {'user_id': '129023175', 'rating': '10'}, {'user_id': '42529388', 'rating': '10'}, {'user_id': '67210457', 'rating': '10'}, {'user_id': '48149329', 'rating': '10'}, {'user_id': '130365299', 'rating': '10'}, {'user_id': '181956199', 'rating': '10'}]
# [{'movie_id': '258687', 'rating': '10'}, {'movie_id': '958722', 'rating': '10'}, {'movie_id': '507440', 'rating': '10'}, {'movie_id': '7360', 'rating': '9'}, {'movie_id': '5003510', 'rating': '8'}, {'movie_id': '875', 'rating': '8'}, {'movie_id': '1048908', 'rating': '10'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Русский трейлер
# Parsed new movie: Трейлер
# [{'movie_id': '258687', 'rating': '10'}]
# [{'movie_id': '819101', 'rating': '10'}, {'movie_id': '2494', 'rating': '9'}, {'movie_id': '195434', 'rating': '9'}, {'movie_id': '104938', 'rating': '10'}, {'movie_id': '838', 'rating': '9'}, {'movie_id': '939411', 'rating': '8'}, {'movie_id': '7466', 'rating': '8'}, {'movie_id': '835086', 'rating': '8'}, {'movie_id': '350', 'rating': '10'}, {'movie_id': '43970', 'rating': '7'}]
# Found 10 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер ре-релиза
# [{'movie_id': '258687', 'rating': '10'}, {'movie_id': '5954', 'rating': '4'}, {'movie_id': '542', 'rating': '8'}, {'movie_id': '3621', 'rating': '6'}, {'movie_id': '1139960', 'rating': '2'}, {'movie_id': '252107', 'rating': '3'}, {'movie_id': '1642', 'rating': '5'}, {'movie_id': '9411', 'rating': '5'}, {'movie_id': '397672', 'rating': '3'}, {'movie_id': '18114', 'rating': '6'}]
# Found 9 new movies to parse
# Parsed new movie: Red-band трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Тизер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# [{'movie_id': '462606', 'rating': '6'}, {'movie_id': '530', 'rating': '9'}, {'movie_id': '606646', 'rating': '7'}, {'movie_id': '7226', 'rating': '8'}, {'movie_id': '4541', 'rating': '7'}, {'movie_id': '81733', 'rating': '7'}, {'movie_id': '649917', 'rating': '7'}, {'movie_id': '1043758', 'rating': '9'}, {'movie_id': '43423', 'rating': '8'}, {'movie_id': '425400', 'rating': '9'}]
# Found 10 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Русский трейлер (дублированный)
# Parsed new movie: Фрагмент «Гони рубль, родсТВенник!»
# Parsed new movie: Трейлер (дублированный)
# Total unique movies: 57
# [{'user_id': '167925617', 'rating': '10'}, {'user_id': '120121492', 'rating': '8'}, {'user_id': '87564299', 'rating': '10'}, {'user_id': '187445459', 'rating': '8'}, {'user_id': '149896721', 'rating': '10'}, {'user_id': '16119244', 'rating': '7'}, {'user_id': '195971979', 'rating': '10'}, {'user_id': '162628654', 'rating': '7'}, {'user_id': '23031343', 'rating': '10'}, {'user_id': '39181997', 'rating': '10'}, {'user_id': '124540143', 'rating': '7'}, {'user_id': '171186760', 'rating': '8'}, {'user_id': '71786136', 'rating': '10'}, {'user_id': '69724765', 'rating': '10'}, {'user_id': '80210192', 'rating': '10'}, {'user_id': '203362295', 'rating': '10'}, {'user_id': '15394745', 'rating': '7'}, {'user_id': '205418932', 'rating': '10'}, {'user_id': '34883675', 'rating': '9'}, {'user_id': '206659320', 'rating': '10'}]
# [{'movie_id': '5417693', 'rating': '10'}, {'movie_id': '6095404', 'rating': '10'}, {'movie_id': '5518231', 'rating': '10'}, {'movie_id': '5367009', 'rating': '1'}, {'movie_id': '5304528', 'rating': '10'}, {'movie_id': '5333364', 'rating': '8'}, {'movie_id': '1228407', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: ТВ-ролик
# [{'movie_id': '5417693', 'rating': '8'}, {'movie_id': '6163953', 'rating': '7'}, {'movie_id': '1249273', 'rating': '10'}, {'movie_id': '4729320', 'rating': '10'}, {'movie_id': '6801973', 'rating': '5'}, {'movie_id': '5364887', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер
# [{'movie_id': '5417693', 'rating': '10'}, {'movie_id': '5428537', 'rating': '10'}, {'movie_id': '5958246', 'rating': '10'}, {'movie_id': '5515407', 'rating': '8'}, {'movie_id': '5333364', 'rating': '8'}]
# Found 3 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Финальный трейлер
# [{'movie_id': '5417693', 'rating': '8'}, {'movie_id': '777032', 'rating': '7'}, {'movie_id': '7088374', 'rating': '8'}, {'movie_id': '5629413', 'rating': '9'}, {'movie_id': '5333364', 'rating': '9'}]
# Found 2 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: ТВ-ролик
# [{'movie_id': '5417693', 'rating': '10'}, {'movie_id': '5308994', 'rating': '7'}, {'movie_id': '46558', 'rating': '7'}, {'movie_id': '5235968', 'rating': '10'}, {'movie_id': '355', 'rating': '8'}, {'movie_id': '462682', 'rating': '10'}, {'movie_id': '15635', 'rating': '2'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Мать (1989)12+
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Total unique movies: 78
# [{'user_id': '155873753', 'rating': '7'}, {'user_id': '123188872', 'rating': '10'}, {'user_id': '14493065', 'rating': '7'}, {'user_id': '107136854', 'rating': '6'}, {'user_id': '149280189', 'rating': '10'}, {'user_id': '23257005', 'rating': '10'}, {'user_id': '55652191', 'rating': '8'}, {'user_id': '34268763', 'rating': '7'}, {'user_id': '48883197', 'rating': '10'}, {'user_id': '65141112', 'rating': '10'}, {'user_id': '22566233', 'rating': '10'}, {'user_id': '20126418', 'rating': '7'}, {'user_id': '137785583', 'rating': '3'}, {'user_id': '100110735', 'rating': '7'}, {'user_id': '192034917', 'rating': '9'}, {'user_id': '104951716', 'rating': '10'}, {'user_id': '43967351', 'rating': '7'}, {'user_id': '170845992', 'rating': '7'}, {'user_id': '94598555', 'rating': '9'}, {'user_id': '28751927', 'rating': '10'}]
# [{'movie_id': '6440213', 'rating': '7'}, {'movie_id': '4476147', 'rating': '9'}, {'movie_id': '5411604', 'rating': '8'}, {'movie_id': '1047881', 'rating': '9'}, {'movie_id': '464942', 'rating': '10'}, {'movie_id': '5427621', 'rating': '5'}, {'movie_id': '1109034', 'rating': '6'}, {'movie_id': '5267722', 'rating': '7'}, {'movie_id': '309408', 'rating': '10'}, {'movie_id': '5378683', 'rating': '8'}]
# Found 9 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# [{'movie_id': '6440213', 'rating': '10'}, {'movie_id': '689', 'rating': '1'}, {'movie_id': '5958246', 'rating': '10'}, {'movie_id': '5230101', 'rating': '10'}, {'movie_id': '4959134', 'rating': '10'}, {'movie_id': '5047471', 'rating': '10'}, {'movie_id': '4766559', 'rating': '10'}, {'movie_id': '839954', 'rating': '10'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# [{'movie_id': '6440213', 'rating': '7'}, {'movie_id': '5333364', 'rating': '10'}, {'movie_id': '1334852', 'rating': '10'}, {'movie_id': '5119634', 'rating': '10'}, {'movie_id': '4485219', 'rating': '1'}, {'movie_id': '4959134', 'rating': '10'}, {'movie_id': '40866', 'rating': '10'}, {'movie_id': '984364', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Интернет-трейлер №2
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Фрагмент
# Parsed new movie: Трейлер №2
# [{'movie_id': '6440213', 'rating': '6'}, {'movie_id': '15067', 'rating': '4'}, {'movie_id': '966995', 'rating': '9'}, {'movie_id': '273302', 'rating': '7'}, {'movie_id': '1237984', 'rating': '9'}, {'movie_id': '526', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер №2 (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер №4 (дублированный)
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Трейлер (русский язык)
# [{'movie_id': '6440213', 'rating': '10'}, {'movie_id': '6332966', 'rating': '10'}]
# Total unique movies: 103
# [{'user_id': '28456180', 'rating': '7'}, {'user_id': '143138322', 'rating': '10'}, {'user_id': '134194099', 'rating': '10'}, {'user_id': '89194690', 'rating': '7'}, {'user_id': '166408519', 'rating': '6'}, {'user_id': '82244331', 'rating': '10'}, {'user_id': '127619945', 'rating': '10'}, {'user_id': '200559126', 'rating': '9'}, {'user_id': '95856141', 'rating': '10'}, {'user_id': '111730617', 'rating': '9'}, {'user_id': '152968559', 'rating': '7'}, {'user_id': '74945878', 'rating': '7'}, {'user_id': '107788960', 'rating': '10'}, {'user_id': '69031903', 'rating': '8'}, {'user_id': '60952749', 'rating': '10'}, {'user_id': '206659320', 'rating': '10'}, {'user_id': '146269259', 'rating': '6'}, {'user_id': '202016696', 'rating': '10'}, {'user_id': '148097574', 'rating': '10'}, {'user_id': '195416509', 'rating': '10'}]
# [{'movie_id': '5965493', 'rating': '7'}, {'movie_id': '1445176', 'rating': '10'}, {'movie_id': '5428538', 'rating': '10'}, {'movie_id': '5518230', 'rating': '10'}, {'movie_id': '4969607', 'rating': '1'}, {'movie_id': '609349', 'rating': '7'}, {'movie_id': '5377802', 'rating': '10'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# [{'movie_id': '5965493', 'rating': '10'}, {'movie_id': '7374031', 'rating': '10'}, {'movie_id': '1142206', 'rating': '10'}, {'movie_id': '988749', 'rating': '10'}, {'movie_id': '5518231', 'rating': '10'}, {'movie_id': '4626783', 'rating': '10'}, {'movie_id': '5024925', 'rating': '9'}, {'movie_id': '4959134', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# [{'movie_id': '5965493', 'rating': '10'}, {'movie_id': '4666604', 'rating': '10'}, {'movie_id': '6332966', 'rating': '10'}, {'movie_id': '42782', 'rating': '10'}]
# Found 2 new movies to parse
# Parsed new movie: Трейлер №2
# Parsed new movie: ТВ-ролик
# [{'movie_id': '5965493', 'rating': '7'}, {'movie_id': '6712512', 'rating': '9'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер
# [{'movie_id': '5965493', 'rating': '6'}]
# Total unique movies: 117
# [{'user_id': '189563738', 'rating': '8'}, {'user_id': '71282305', 'rating': '10'}, {'user_id': '78972868', 'rating': '7'}, {'user_id': '173815275', 'rating': '10'}, {'user_id': '116382694', 'rating': '10'}, {'user_id': '196743529', 'rating': '10'}, {'user_id': '29145591', 'rating': '10'}, {'user_id': '209088174', 'rating': '8'}, {'user_id': '142462320', 'rating': '9'}, {'user_id': '90884117', 'rating': '1'}, {'user_id': '151362353', 'rating': '10'}, {'user_id': '163830849', 'rating': '6'}, {'user_id': '81486676', 'rating': '8'}, {'user_id': '93152213', 'rating': '10'}, {'user_id': '157191220', 'rating': '8'}, {'user_id': '125236951', 'rating': '7'}, {'user_id': '41879490', 'rating': '10'}, {'user_id': '203643485', 'rating': '8'}, {'user_id': '176949529', 'rating': '9'}, {'user_id': '17179891', 'rating': '8'}]
# [{'movie_id': '6332966', 'rating': '8'}, {'movie_id': '484628', 'rating': '7'}, {'movie_id': '253761', 'rating': '7'}, {'movie_id': '415687', 'rating': '7'}, {'movie_id': '5366081', 'rating': '8'}, {'movie_id': '584405', 'rating': '10'}, {'movie_id': '4312553', 'rating': '8'}, {'movie_id': '5275429', 'rating': '10'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер
# [{'movie_id': '6332966', 'rating': '10'}, {'movie_id': '5203768', 'rating': '10'}, {'movie_id': '5428538', 'rating': '10'}, {'movie_id': '5495322', 'rating': '5'}, {'movie_id': '5121262', 'rating': '10'}, {'movie_id': '5504100', 'rating': '7'}, {'movie_id': '5304528', 'rating': '10'}]
# Found 4 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# [{'movie_id': '6332966', 'rating': '7'}, {'movie_id': '5364887', 'rating': '10'}, {'movie_id': '5120001', 'rating': '5'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '6332966', 'rating': '10'}, {'movie_id': '5421871', 'rating': '10'}, {'movie_id': '5965493', 'rating': '10'}, {'movie_id': '6092619', 'rating': '10'}, {'movie_id': '5333364', 'rating': '10'}, {'movie_id': '5304528', 'rating': '10'}, {'movie_id': '5411604', 'rating': '10'}]
# Found 2 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (дублированный)
# [{'movie_id': '6332966', 'rating': '10'}, {'movie_id': '1326397', 'rating': '10'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер
# Total unique movies: 132
# [{'user_id': '135253779', 'rating': '10'}, {'user_id': '29807483', 'rating': '8'}, {'user_id': '31290337', 'rating': '10'}, {'user_id': '34331472', 'rating': '10'}, {'user_id': '14777812', 'rating': '1'}, {'user_id': '28496638', 'rating': '7'}, {'user_id': '32529170', 'rating': '4'}, {'user_id': '174726040', 'rating': '10'}, {'user_id': '91280085', 'rating': '8'}, {'user_id': '3750445', 'rating': '8'}, {'user_id': '168488212', 'rating': '10'}, {'user_id': '22570186', 'rating': '10'}, {'user_id': '188208846', 'rating': '8'}, {'user_id': '104415565', 'rating': '9'}, {'user_id': '159972331', 'rating': '9'}, {'user_id': '38623396', 'rating': '8'}, {'user_id': '19892213', 'rating': '5'}, {'user_id': '197592667', 'rating': '10'}, {'user_id': '165232634', 'rating': '2'}, {'user_id': '3119385', 'rating': '7'}]
# [{'movie_id': '5333364', 'rating': '10'}, {'movie_id': '6163953', 'rating': '10'}, {'movie_id': '880665', 'rating': '10'}, {'movie_id': '4550354', 'rating': '10'}, {'movie_id': '1199529', 'rating': '10'}]
# Found 3 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2
# [{'movie_id': '5333364', 'rating': '8'}, {'movie_id': '418762', 'rating': '5'}, {'movie_id': '84830', 'rating': '8'}, {'movie_id': '5450038', 'rating': '7'}, {'movie_id': '103412', 'rating': '1'}, {'movie_id': '4369222', 'rating': '1'}, {'movie_id': '4745337', 'rating': '10'}, {'movie_id': '4414587', 'rating': '7'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Финальный трейлер (дублированный)
# Parsed new movie: Трейлер №2 (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '5333364', 'rating': '10'}, {'movie_id': '4476147', 'rating': '10'}, {'movie_id': '5427621', 'rating': '10'}]
# [{'movie_id': '5333364', 'rating': '10'}, {'movie_id': '4886624', 'rating': '10'}, {'movie_id': '1334852', 'rating': '10'}, {'movie_id': '5230101', 'rating': '10'}, {'movie_id': '5047464', 'rating': '10'}, {'movie_id': '532967', 'rating': '10'}, {'movie_id': '5367009', 'rating': '10'}]
# Found 3 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# [{'movie_id': '5333364', 'rating': '1'}, {'movie_id': '5367009', 'rating': '10'}, {'movie_id': '5313869', 'rating': '1'}, {'movie_id': '1112132', 'rating': '10'}, {'movie_id': '5504261', 'rating': '4'}, {'movie_id': '6267717', 'rating': '10'}, {'movie_id': '1112153', 'rating': '10'}, {'movie_id': '1275100', 'rating': '1'}, {'movie_id': '4957174', 'rating': '1'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №3 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: ТВ-ролик
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Жуткая невеста (2020)18+
# Parsed new movie: Трейлер №2
# Total unique movies: 152
# [{'user_id': '11725397', 'rating': '7'}, {'user_id': '80563966', 'rating': '6'}, {'user_id': '138250500', 'rating': '6'}, {'user_id': '46141681', 'rating': '10'}, {'user_id': '35403457', 'rating': '6'}, {'user_id': '38421962', 'rating': '10'}, {'user_id': '25503864', 'rating': '10'}, {'user_id': '175453552', 'rating': '8'}, {'user_id': '94803831', 'rating': '2'}, {'user_id': '90884117', 'rating': '7'}, {'user_id': '18208904', 'rating': '7'}, {'user_id': '208289362', 'rating': '1'}, {'user_id': '31904933', 'rating': '8'}, {'user_id': '1306257', 'rating': '5'}, {'user_id': '1487084', 'rating': '4'}, {'user_id': '2445777', 'rating': '7'}, {'user_id': '244946', 'rating': '3'}, {'user_id': '4475917', 'rating': '7'}, {'user_id': '97162822', 'rating': '1'}, {'user_id': '3070608', 'rating': '5'}]
# [{'movie_id': '1229683', 'rating': '7'}, {'movie_id': '1287545', 'rating': '7'}, {'movie_id': '1229684', 'rating': '7'}, {'movie_id': '926540', 'rating': '7'}, {'movie_id': '460432', 'rating': '6'}, {'movie_id': '680149', 'rating': '9'}, {'movie_id': '678549', 'rating': '8'}, {'movie_id': '817971', 'rating': '5'}, {'movie_id': '50881', 'rating': '8'}, {'movie_id': '5278126', 'rating': '6'}]
# Found 9 new movies to parse
# Parsed new movie: Финальный трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# [{'movie_id': '1229683', 'rating': '6'}, {'movie_id': '1115213', 'rating': '7'}, {'movie_id': '595', 'rating': '8'}, {'movie_id': '1237984', 'rating': '7'}, {'movie_id': '5928', 'rating': '8'}, {'movie_id': '8124', 'rating': '8'}, {'movie_id': '5237443', 'rating': '5'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '1229683', 'rating': '6'}, {'movie_id': '822709', 'rating': '8'}, {'movie_id': '1282688', 'rating': '6'}, {'movie_id': '1048253', 'rating': '7'}, {'movie_id': '1320623', 'rating': '6'}, {'movie_id': '484457', 'rating': '7'}, {'movie_id': '2022', 'rating': '7'}, {'movie_id': '2053', 'rating': '7'}, {'movie_id': '102611', 'rating': '7'}, {'movie_id': '413447', 'rating': '7'}]
# Found 9 new movies to parse
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Международный трейлер (дублированный)
# [{'movie_id': '1229683', 'rating': '10'}, {'movie_id': '5518329', 'rating': '10'}, {'movie_id': '5067597', 'rating': '10'}, {'movie_id': '1325596', 'rating': '8'}, {'movie_id': '5282068', 'rating': '7'}, {'movie_id': '4358019', 'rating': '8'}, {'movie_id': '1112132', 'rating': '10'}, {'movie_id': '1165026', 'rating': '10'}, {'movie_id': '534930', 'rating': '10'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (дублированный)
# [{'movie_id': '2928', 'rating': '8'}, {'movie_id': '472386', 'rating': '7'}, {'movie_id': '3908', 'rating': '9'}, {'movie_id': '535341', 'rating': '9'}, {'movie_id': '1229683', 'rating': '6'}, {'movie_id': '437410', 'rating': '8'}, {'movie_id': '1347949', 'rating': '8'}, {'movie_id': '7088374', 'rating': '6'}]
# Found 3 new movies to parse
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер №2 (русский язык)
# Total unique movies: 185
# [{'user_id': '164975166', 'rating': '9'}, {'user_id': '128251938', 'rating': '8'}, {'user_id': '190712480', 'rating': '10'}, {'user_id': '172634656', 'rating': '10'}, {'user_id': '111981743', 'rating': '9'}, {'user_id': '41252131', 'rating': '8'}, {'user_id': '23052352', 'rating': '10'}, {'user_id': '37956320', 'rating': '8'}, {'user_id': '80548166', 'rating': '10'}, {'user_id': '205801120', 'rating': '8'}, {'user_id': '35403457', 'rating': '8'}, {'user_id': '21897544', 'rating': '8'}, {'user_id': '181651613', 'rating': '8'}, {'user_id': '146039692', 'rating': '8'}, {'user_id': '169344543', 'rating': '10'}, {'user_id': '59643838', 'rating': '3'}, {'user_id': '83835285', 'rating': '10'}, {'user_id': '95695186', 'rating': '8'}, {'user_id': '22268027', 'rating': '9'}, {'user_id': '139595896', 'rating': '1'}]
# [{'movie_id': '437410', 'rating': '9'}, {'movie_id': '45180', 'rating': '3'}, {'movie_id': '230671', 'rating': '9'}, {'movie_id': '2011', 'rating': '9'}, {'movie_id': '80749', 'rating': '10'}, {'movie_id': '921938', 'rating': '3'}]
# Found 5 new movies to parse
# Parsed new movie: Фрагмент
# Parsed new movie: Варвар (2003)Barbarian
# Parsed new movie: Трейлер
# Parsed new movie: Начало фильма
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '8067', 'rating': '7'}, {'movie_id': '493222', 'rating': '6'}, {'movie_id': '2821', 'rating': '7'}, {'movie_id': '1541', 'rating': '7'}, {'movie_id': '712', 'rating': '7'}, {'movie_id': '81491', 'rating': '7'}, {'movie_id': '3775', 'rating': '7'}, {'movie_id': '6218', 'rating': '7'}, {'movie_id': '693', 'rating': '7'}, {'movie_id': '686', 'rating': '7'}]
# Found 10 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# [{'movie_id': '47237', 'rating': '10'}, {'movie_id': '437410', 'rating': '10'}, {'movie_id': '57004', 'rating': '10'}, {'movie_id': '5118247', 'rating': '10'}, {'movie_id': '12198', 'rating': '10'}, {'movie_id': '729', 'rating': '10'}, {'movie_id': '1108577', 'rating': '10'}, {'movie_id': '3563', 'rating': '10'}, {'movie_id': '2443', 'rating': '10'}]
# Found 8 new movies to parse
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: DVD-трейлер (русский язык)
# Parsed new movie: Трейлер 4K-реставрации (русские субтитры)
# [{'movie_id': '437410', 'rating': '10'}, {'movie_id': '5364887', 'rating': '10'}, {'movie_id': '1207545', 'rating': '10'}, {'movie_id': '5407484', 'rating': '10'}, {'movie_id': '5428537', 'rating': '10'}, {'movie_id': '418794', 'rating': '10'}]
# Found 3 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '437410', 'rating': '9'}, {'movie_id': '111543', 'rating': '9'}, {'movie_id': '47237', 'rating': '9'}, {'movie_id': '5105855', 'rating': '7'}, {'movie_id': '42571', 'rating': '4'}, {'movie_id': '5223', 'rating': '5'}, {'movie_id': '77439', 'rating': '8'}, {'movie_id': '197243', 'rating': '8'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Международный трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# Total unique movies: 216
# [{'user_id': '185928564', 'rating': '10'}, {'user_id': '204351472', 'rating': '1'}, {'user_id': '144913198', 'rating': '9'}, {'user_id': '55344440', 'rating': '8'}, {'user_id': '77943586', 'rating': '6'}, {'user_id': '210304343', 'rating': '10'}, {'user_id': '21041838', 'rating': '2'}, {'user_id': '120267505', 'rating': '10'}, {'user_id': '183890375', 'rating': '1'}, {'user_id': '38245240', 'rating': '8'}, {'user_id': '198656501', 'rating': '10'}, {'user_id': '6121143', 'rating': '8'}, {'user_id': '111071663', 'rating': '8'}, {'user_id': '119292414', 'rating': '9'}, {'user_id': '209739373', 'rating': '7'}, {'user_id': '67455135', 'rating': '8'}, {'user_id': '30383386', 'rating': '10'}, {'user_id': '162350918', 'rating': '10'}, {'user_id': '38722965', 'rating': '10'}, {'user_id': '15261159', 'rating': '8'}]
# [{'movie_id': '1347949', 'rating': '10'}]
# [{'movie_id': '1347949', 'rating': '1'}]
# [{'movie_id': '40666', 'rating': '3'}, {'movie_id': '582170', 'rating': '8'}, {'movie_id': '740', 'rating': '1'}, {'movie_id': '3950', 'rating': '4'}, {'movie_id': '5091', 'rating': '8'}, {'movie_id': '5932', 'rating': '8'}, {'movie_id': '930534', 'rating': '8'}, {'movie_id': '581651', 'rating': '7'}, {'movie_id': '487409', 'rating': '7'}, {'movie_id': '79072', 'rating': '8'}]
# Found 10 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '1347949', 'rating': '8'}, {'movie_id': '992605', 'rating': '10'}, {'movie_id': '1243061', 'rating': '4'}, {'movie_id': '63912', 'rating': '10'}, {'movie_id': '6944852', 'rating': '9'}, {'movie_id': '939785', 'rating': '10'}, {'movie_id': '7651', 'rating': '8'}, {'movie_id': '88071', 'rating': '8'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер №3
# Parsed new movie: Трейлер №3 (дублированный)
# Parsed new movie: Русский ТВ-ролик
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Международный трейлер
# Parsed new movie: Трейлер №2 (русский язык)
# [{'movie_id': '8224', 'rating': '6'}, {'movie_id': '678124', 'rating': '7'}, {'movie_id': '1112803', 'rating': '6'}, {'movie_id': '6046385', 'rating': '7'}, {'movie_id': '675788', 'rating': '7'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер 4K-реставрации (русские субтитры)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русские субтитры)
# Total unique movies: 238
# [{'user_id': '2601439', 'rating': '7'}, {'user_id': '72296267', 'rating': '10'}, {'user_id': '187582360', 'rating': '4'}, {'user_id': '70557808', 'rating': '8'}, {'user_id': '135981069', 'rating': '1'}, {'user_id': '6280433', 'rating': '7'}, {'user_id': '5307479', 'rating': '6'}, {'user_id': '15716868', 'rating': '7'}, {'user_id': '81938042', 'rating': '7'}, {'user_id': '108959688', 'rating': '6'}, {'user_id': '87563119', 'rating': '8'}, {'user_id': '2825861', 'rating': '7'}, {'user_id': '53178717', 'rating': '10'}, {'user_id': '106911772', 'rating': '7'}, {'user_id': '22191957', 'rating': '7'}, {'user_id': '16979512', 'rating': '10'}, {'user_id': '194308618', 'rating': '9'}, {'user_id': '107085151', 'rating': '6'}, {'user_id': '37648989', 'rating': '7'}, {'user_id': '34266300', 'rating': '7'}]
# [{'movie_id': '7088374', 'rating': '7'}, {'movie_id': '377', 'rating': '10'}, {'movie_id': '1199016', 'rating': '7'}, {'movie_id': '3984', 'rating': '7'}, {'movie_id': '805650', 'rating': '7'}, {'movie_id': '64760', 'rating': '5'}, {'movie_id': '842950', 'rating': '4'}, {'movie_id': '5202999', 'rating': '3'}, {'movie_id': '835877', 'rating': '4'}, {'movie_id': '12330', 'rating': '8'}]
# Found 9 new movies to parse
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер
# [{'movie_id': '7088374', 'rating': '10'}, {'movie_id': '635', 'rating': '10'}, {'movie_id': '1140565', 'rating': '10'}, {'movie_id': '677798', 'rating': '9'}, {'movie_id': '5364390', 'rating': '10'}, {'movie_id': '535341', 'rating': '10'}, {'movie_id': '5353117', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# [{'movie_id': '7088374', 'rating': '4'}, {'movie_id': '569153', 'rating': '4'}, {'movie_id': '5454708', 'rating': '8'}, {'movie_id': '1068711', 'rating': '5'}, {'movie_id': '4968926', 'rating': '5'}, {'movie_id': '4745604', 'rating': '10'}, {'movie_id': '674295', 'rating': '10'}, {'movie_id': '1200603', 'rating': '10'}, {'movie_id': '910207', 'rating': '1'}, {'movie_id': '4478010', 'rating': '1'}]
# Found 9 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# [{'movie_id': '7088374', 'rating': '8'}, {'movie_id': '5417580', 'rating': '8'}, {'movie_id': '5449125', 'rating': '7'}, {'movie_id': '7876323', 'rating': '5'}, {'movie_id': '6299997', 'rating': '10'}, {'movie_id': '1289334', 'rating': '3'}, {'movie_id': '5453737', 'rating': '8'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '7088374', 'rating': '1'}, {'movie_id': '1047492', 'rating': '7'}, {'movie_id': '61439', 'rating': '8'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер
# Total unique movies: 268
# [{'user_id': '65184740', 'rating': '10'}, {'user_id': '6214410', 'rating': '7'}, {'user_id': '35803239', 'rating': '10'}, {'user_id': '74003375', 'rating': '10'}, {'user_id': '193546690', 'rating': '10'}, {'user_id': '160742870', 'rating': '5'}, {'user_id': '160504418', 'rating': '10'}, {'user_id': '101786617', 'rating': '8'}, {'user_id': '40094595', 'rating': '9'}, {'user_id': '17209903', 'rating': '10'}, {'user_id': '114562058', 'rating': '1'}, {'user_id': '13648701', 'rating': '6'}, {'user_id': '198674126', 'rating': '10'}, {'user_id': '100579702', 'rating': '7'}, {'user_id': '101483084', 'rating': '7'}, {'user_id': '16831996', 'rating': '10'}, {'user_id': '50677074', 'rating': '10'}, {'user_id': '39898411', 'rating': '6'}, {'user_id': '19900312', 'rating': '7'}, {'user_id': '84578719', 'rating': '10'}]
# [{'movie_id': '1047492', 'rating': '10'}]
# [{'movie_id': '1047492', 'rating': '7'}, {'movie_id': '1229683', 'rating': '8'}, {'movie_id': '6782779', 'rating': '10'}, {'movie_id': '843538', 'rating': '6'}, {'movie_id': '5905715', 'rating': '3'}, {'movie_id': '5445182', 'rating': '7'}, {'movie_id': '5278126', 'rating': '3'}, {'movie_id': '5504313', 'rating': '8'}, {'movie_id': '6374012', 'rating': '8'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '1047492', 'rating': '10'}, {'movie_id': '4476147', 'rating': '7'}, {'movie_id': '1405508', 'rating': '10'}, {'movie_id': '977990', 'rating': '7'}, {'movie_id': '6452', 'rating': '10'}, {'movie_id': '42381', 'rating': '8'}, {'movie_id': '1097478', 'rating': '7'}, {'movie_id': '5129252', 'rating': '8'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Ты — мне, я — тебе (1976)0+
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# [{'movie_id': '1047492', 'rating': '10'}, {'movie_id': '863', 'rating': '7'}, {'movie_id': '916105', 'rating': '10'}, {'movie_id': '4626783', 'rating': '10'}, {'movie_id': '5995316', 'rating': '7'}, {'movie_id': '654749', 'rating': '10'}, {'movie_id': '851808', 'rating': '10'}, {'movie_id': '491816', 'rating': '5'}, {'movie_id': '5949652', 'rating': '10'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '1047492', 'rating': '10'}]
# Total unique movies: 287
# [{'user_id': '58462705', 'rating': '7'}, {'user_id': '166143305', 'rating': '1'}, {'user_id': '169925042', 'rating': '6'}, {'user_id': '3479558', 'rating': '1'}, {'user_id': '147121950', 'rating': '8'}, {'user_id': '90884117', 'rating': '7'}, {'user_id': '728293', 'rating': '6'}, {'user_id': '129990784', 'rating': '1'}, {'user_id': '89009828', 'rating': '7'}, {'user_id': '61923362', 'rating': '1'}, {'user_id': '2863268', 'rating': '6'}, {'user_id': '35211501', 'rating': '7'}, {'user_id': '155978723', 'rating': '1'}, {'user_id': '151494223', 'rating': '7'}, {'user_id': '16739540', 'rating': '6'}, {'user_id': '136639775', 'rating': '6'}, {'user_id': '108474324', 'rating': '6'}, {'user_id': '156861104', 'rating': '10'}, {'user_id': '121702385', 'rating': '10'}, {'user_id': '18793977', 'rating': '4'}]
# [{'movie_id': '4826207', 'rating': '7'}, {'movie_id': '5146965', 'rating': '7'}, {'movie_id': '5001443', 'rating': '6'}, {'movie_id': '823956', 'rating': '8'}, {'movie_id': '5450952', 'rating': '6'}, {'movie_id': '316', 'rating': '7'}, {'movie_id': '299', 'rating': '7'}, {'movie_id': '301', 'rating': '7'}, {'movie_id': '1264589', 'rating': '6'}]
# Found 8 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Тизер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер к 20-летию фильма (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '4826207', 'rating': '1'}]
# [{'movie_id': '4826207', 'rating': '6'}, {'movie_id': '5450952', 'rating': '8'}, {'movie_id': '5433378', 'rating': '10'}, {'movie_id': '5495322', 'rating': '9'}, {'movie_id': '4645941', 'rating': '9'}, {'movie_id': '916491', 'rating': '10'}]
# Found 3 new movies to parse
# Parsed new movie: Тихий человек (2024)18+
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# [{'movie_id': '1346361', 'rating': '3'}, {'movie_id': '8651272', 'rating': '1'}, {'movie_id': '8538013', 'rating': '1'}, {'movie_id': '4826207', 'rating': '1'}, {'movie_id': '7787997', 'rating': '1'}, {'movie_id': '1235147', 'rating': '1'}, {'movie_id': '7277489', 'rating': '5'}, {'movie_id': '1337679', 'rating': '4'}, {'movie_id': '1164809', 'rating': '6'}, {'movie_id': '6573394', 'rating': '7'}]
# Found 9 new movies to parse
# Parsed new movie: Интернет-трейлер
# Parsed new movie: А там посмотрим (2025)E poi si vede
# Parsed new movie: Трейлер
# Parsed new movie: Ick
# Parsed new movie: Silent Partners
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2
# [{'movie_id': '4826207', 'rating': '8'}, {'movie_id': '586498', 'rating': '10'}, {'movie_id': '7239312', 'rating': '10'}, {'movie_id': '1201973', 'rating': '1'}, {'movie_id': '6581558', 'rating': '1'}, {'movie_id': '6303864', 'rating': '10'}, {'movie_id': '5235275', 'rating': '7'}, {'movie_id': '4518317', 'rating': '6'}, {'movie_id': '5275429', 'rating': '10'}, {'movie_id': '397667', 'rating': '9'}]
# Found 8 new movies to parse
# Parsed new movie: Проморолик
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Смертельный квест (ТВ, 2018)No Escape Room
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер ре-релиза (дублированный)
# Total unique movies: 315
# [{'user_id': '90927197', 'rating': '9'}, {'user_id': '46148092', 'rating': '10'}, {'user_id': '161854132', 'rating': '10'}, {'user_id': '83892046', 'rating': '7'}, {'user_id': '15872765', 'rating': '9'}, {'user_id': '64587945', 'rating': '4'}, {'user_id': '137169267', 'rating': '10'}, {'user_id': '16483082', 'rating': '8'}, {'user_id': '74055076', 'rating': '10'}, {'user_id': '80769788', 'rating': '7'}, {'user_id': '22699419', 'rating': '10'}, {'user_id': '81287442', 'rating': '7'}, {'user_id': '137247347', 'rating': '2'}, {'user_id': '39645141', 'rating': '3'}, {'user_id': '130591479', 'rating': '6'}, {'user_id': '139020264', 'rating': '9'}, {'user_id': '2844188', 'rating': '6'}, {'user_id': '2174526', 'rating': '7'}, {'user_id': '193977280', 'rating': '10'}, {'user_id': '6772860', 'rating': '9'}]
# [{'movie_id': '7229988', 'rating': '9'}, {'movie_id': '5160497', 'rating': '10'}, {'movie_id': '841472', 'rating': '9'}, {'movie_id': '278273', 'rating': '9'}]
# Found 3 new movies to parse
# Parsed new movie: Тизер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '7229988', 'rating': '10'}, {'movie_id': '1047881', 'rating': '10'}, {'movie_id': '840754', 'rating': '10'}, {'movie_id': '5235968', 'rating': '10'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер
# [{'movie_id': '7229988', 'rating': '10'}, {'movie_id': '937438', 'rating': '10'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер (русские субтитры)
# [{'movie_id': '7229988', 'rating': '7'}, {'movie_id': '5437097', 'rating': '7'}, {'movie_id': '1262160', 'rating': '9'}, {'movie_id': '1389108', 'rating': '6'}, {'movie_id': '5457984', 'rating': '7'}, {'movie_id': '7144323', 'rating': '7'}, {'movie_id': '4368100', 'rating': '7'}, {'movie_id': '7611', 'rating': '7'}, {'movie_id': '596266', 'rating': '7'}, {'movie_id': '23737', 'rating': '6'}]
# Found 9 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# [{'movie_id': '7229988', 'rating': '9'}, {'movie_id': '1436464', 'rating': '8'}, {'movie_id': '264829', 'rating': '9'}, {'movie_id': '1318972', 'rating': '9'}, {'movie_id': '1009626', 'rating': '9'}, {'movie_id': '1047956', 'rating': '10'}, {'movie_id': '463070', 'rating': '10'}, {'movie_id': '413362', 'rating': '10'}, {'movie_id': '252107', 'rating': '10'}, {'movie_id': '406408', 'rating': '10'}]
# Found 8 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Total unique movies: 337
# [{'user_id': '23939094', 'rating': '10'}, {'user_id': '46367839', 'rating': '4'}, {'user_id': '29501857', 'rating': '4'}, {'user_id': '188024355', 'rating': '10'}, {'user_id': '75521269', 'rating': '8'}, {'user_id': '70929611', 'rating': '9'}, {'user_id': '84678993', 'rating': '10'}, {'user_id': '103385056', 'rating': '10'}, {'user_id': '44852768', 'rating': '1'}, {'user_id': '151600913', 'rating': '10'}, {'user_id': '36202297', 'rating': '10'}, {'user_id': '161886809', 'rating': '7'}, {'user_id': '195428288', 'rating': '10'}, {'user_id': '176215969', 'rating': '10'}, {'user_id': '5353358', 'rating': '7'}, {'user_id': '17177747', 'rating': '5'}, {'user_id': '15166296', 'rating': '1'}, {'user_id': '136571856', 'rating': '6'}, {'user_id': '181651613', 'rating': '3'}, {'user_id': '30394432', 'rating': '10'}]
# [{'movie_id': '1047736', 'rating': '10'}, {'movie_id': '6561460', 'rating': '10'}, {'movie_id': '5203768', 'rating': '10'}, {'movie_id': '6429304', 'rating': '10'}, {'movie_id': '42326', 'rating': '10'}, {'movie_id': '43608', 'rating': '10'}, {'movie_id': '22803', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Фрагмент
# Parsed new movie: Самогонщики (1962)12+
# Parsed new movie: Трейлер
# [{'movie_id': '439', 'rating': '8'}, {'movie_id': '43890', 'rating': '8'}, {'movie_id': '57004', 'rating': '7'}, {'movie_id': '45524', 'rating': '9'}, {'movie_id': '25108', 'rating': '10'}, {'movie_id': '44386', 'rating': '9'}, {'movie_id': '42610', 'rating': '8'}, {'movie_id': '591789', 'rating': '5'}, {'movie_id': '544226', 'rating': '7'}]
# Found 8 new movies to parse
# Parsed new movie: Трейлер ре-релиза (русские субтитры)
# Parsed new movie: Трейлер
# Parsed new movie: Фрагмент
# Parsed new movie: Трейлер колоризованной версии
# Parsed new movie: Фрагмент №1
# Parsed new movie: Польский трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '1047736', 'rating': '4'}, {'movie_id': '854', 'rating': '10'}, {'movie_id': '1267348', 'rating': '10'}, {'movie_id': '760904', 'rating': '10'}, {'movie_id': '5203757', 'rating': '8'}, {'movie_id': '51781', 'rating': '10'}, {'movie_id': '195394', 'rating': '9'}, {'movie_id': '5450038', 'rating': '8'}, {'movie_id': '5594', 'rating': '9'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Интернет-трейлер
# Parsed new movie: Фрагмент
# Parsed new movie: Международный трейлер №2 (дублированный)
# Parsed new movie: Трейлер
# [{'movie_id': '1047736', 'rating': '10'}, {'movie_id': '5248892', 'rating': '10'}, {'movie_id': '410267', 'rating': '10'}, {'movie_id': '4481054', 'rating': '10'}, {'movie_id': '441406', 'rating': '10'}, {'movie_id': '4511069', 'rating': '10'}, {'movie_id': '1017338', 'rating': '10'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '1047736', 'rating': '8'}, {'movie_id': '14339', 'rating': '9'}, {'movie_id': '474', 'rating': '9'}, {'movie_id': '5452393', 'rating': '10'}, {'movie_id': '5405057', 'rating': '3'}, {'movie_id': '84674', 'rating': '10'}, {'movie_id': '12362', 'rating': '10'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Трейлер №2
# Parsed new movie: Трейлер №2 (русский язык)
# Total unique movies: 369
# ...
# [{'movie_id': '819101', 'rating': '10'}, {'movie_id': '5273', 'rating': '10'}, {'movie_id': '9691', 'rating': '10'}, {'movie_id': '195334', 'rating': '10'}, {'movie_id': '586397', 'rating': '10'}, {'movie_id': '689', 'rating': '10'}, {'movie_id': '325', 'rating': '10'}, {'movie_id': '430', 'rating': '10'}, {'movie_id': '389', 'rating': '10'}, {'movie_id': '448', 'rating': '10'}]
# Found 8 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Международный трейлер (русский язык)
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Трейлер к 50-летию фильма (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# [{'movie_id': '819101', 'rating': '10'}, {'movie_id': '2494', 'rating': '9'}, {'movie_id': '195434', 'rating': '9'}, {'movie_id': '104938', 'rating': '10'}, {'movie_id': '838', 'rating': '9'}, {'movie_id': '939411', 'rating': '8'}, {'movie_id': '7466', 'rating': '8'}, {'movie_id': '835086', 'rating': '8'}, {'movie_id': '350', 'rating': '10'}, {'movie_id': '43970', 'rating': '7'}]
# [{'movie_id': '671', 'rating': '7'}, {'movie_id': '391085', 'rating': '7'}, {'movie_id': '4606', 'rating': '7'}, {'movie_id': '2011', 'rating': '7'}, {'movie_id': '87789', 'rating': '7'}, {'movie_id': '3948', 'rating': '6'}, {'movie_id': '102510', 'rating': '6'}, {'movie_id': '580661', 'rating': '7'}, {'movie_id': '2602', 'rating': '7'}, {'movie_id': '468958', 'rating': '6'}]
# Found 9 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №3 (русский язык)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '462606', 'rating': '6'}, {'movie_id': '530', 'rating': '9'}, {'movie_id': '606646', 'rating': '7'}, {'movie_id': '7226', 'rating': '8'}, {'movie_id': '4541', 'rating': '7'}, {'movie_id': '81733', 'rating': '7'}, {'movie_id': '649917', 'rating': '7'}, {'movie_id': '1043758', 'rating': '9'}, {'movie_id': '43423', 'rating': '8'}, {'movie_id': '425400', 'rating': '9'}]
# [{'movie_id': '555', 'rating': '10'}, {'movie_id': '65770', 'rating': '10'}, {'movie_id': '403', 'rating': '6'}, {'movie_id': '572032', 'rating': '7'}, {'movie_id': '7360', 'rating': '6'}, {'movie_id': '391', 'rating': '6'}, {'movie_id': '4695', 'rating': '7'}, {'movie_id': '1047883', 'rating': '8'}, {'movie_id': '47015', 'rating': '8'}, {'movie_id': '44972', 'rating': '8'}]
# Found 3 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Интернет-трейлер №2 (дублированный)
# Parsed new movie: Трейлер ре-релиза (русские субтитры)
# Total unique movies: 673
# [{'user_id': '85981419', 'rating': '10'}, {'user_id': '4051792', 'rating': '9'}, {'user_id': '117169593', 'rating': '9'}, {'user_id': '3010389', 'rating': '4'}, {'user_id': '40083608', 'rating': '9'}, {'user_id': '132737895', 'rating': '8'}, {'user_id': '629454', 'rating': '10'}, {'user_id': '206630725', 'rating': '10'}, {'user_id': '14163882', 'rating': '8'}, {'user_id': '84819272', 'rating': '8'}, {'user_id': '144913198', 'rating': '10'}, {'user_id': '78111566', 'rating': '10'}, {'user_id': '175231713', 'rating': '10'}, {'user_id': '121588950', 'rating': '10'}, {'user_id': '201341799', 'rating': '1'}, {'user_id': '85028444', 'rating': '7'}, {'user_id': '15258847', 'rating': '7'}, {'user_id': '2825185', 'rating': '7'}, {'user_id': '106767118', 'rating': '10'}, {'user_id': '57183835', 'rating': '10'}]
# [{'movie_id': '7226', 'rating': '8'}, {'movie_id': '2494', 'rating': '10'}, {'movie_id': '5405057', 'rating': '10'}, {'movie_id': '4395219', 'rating': '9'}, {'movie_id': '929885', 'rating': '8'}, {'movie_id': '893362', 'rating': '8'}, {'movie_id': '573869', 'rating': '9'}, {'movie_id': '259251', 'rating': '9'}, {'movie_id': '843831', 'rating': '8'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер ре-релиза (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №3 (дублированный)
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# [{'movie_id': '652833', 'rating': '8'}, {'movie_id': '5456450', 'rating': '8'}, {'movie_id': '2494', 'rating': '9'}, {'movie_id': '3491', 'rating': '8'}, {'movie_id': '420224', 'rating': '4'}, {'movie_id': '401177', 'rating': '5'}, {'movie_id': '1290942', 'rating': '5'}, {'movie_id': '376446', 'rating': '10'}, {'movie_id': '12090', 'rating': '8'}, {'movie_id': '261636', 'rating': '6'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №3 (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# [{'movie_id': '819101', 'rating': '10'}, {'movie_id': '2494', 'rating': '9'}, {'movie_id': '195434', 'rating': '9'}, {'movie_id': '104938', 'rating': '10'}, {'movie_id': '838', 'rating': '9'}, {'movie_id': '939411', 'rating': '8'}, {'movie_id': '7466', 'rating': '8'}, {'movie_id': '835086', 'rating': '8'}, {'movie_id': '350', 'rating': '10'}, {'movie_id': '43970', 'rating': '7'}]
# [{'movie_id': '2494', 'rating': '4'}, {'movie_id': '468', 'rating': '4'}, {'movie_id': '2276', 'rating': '6'}, {'movie_id': '1229683', 'rating': '7'}, {'movie_id': '798', 'rating': '7'}, {'movie_id': '6163953', 'rating': '5'}, {'movie_id': '5501395', 'rating': '3'}, {'movie_id': '1287545', 'rating': '4'}, {'movie_id': '6441870', 'rating': '4'}, {'movie_id': '41283', 'rating': '6'}]
# Found 6 new movies to parse
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Фрагмент
# [{'movie_id': '2494', 'rating': '9'}, {'movie_id': '342', 'rating': '10'}, {'movie_id': '444', 'rating': '9'}, {'movie_id': '448', 'rating': '10'}, {'movie_id': '3498', 'rating': '10'}, {'movie_id': '397667', 'rating': '10'}, {'movie_id': '435', 'rating': '10'}, {'movie_id': '1143242', 'rating': '10'}, {'movie_id': '326', 'rating': '10'}, {'movie_id': '258687', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер отреставрированной версии (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Total unique movies: 695
# [{'user_id': '13769865', 'rating': '8'}, {'user_id': '22858897', 'rating': '7'}, {'user_id': '16449934', 'rating': '8'}, {'user_id': '142052687', 'rating': '6'}, {'user_id': '117169593', 'rating': '9'}, {'user_id': '185679821', 'rating': '10'}, {'user_id': '60255706', 'rating': '8'}, {'user_id': '22239107', 'rating': '9'}, {'user_id': '30740499', 'rating': '7'}, {'user_id': '167159780', 'rating': '1'}, {'user_id': '153334451', 'rating': '7'}, {'user_id': '42874021', 'rating': '9'}, {'user_id': '131314009', 'rating': '8'}, {'user_id': '13635322', 'rating': '2'}, {'user_id': '93857651', 'rating': '10'}, {'user_id': '195941451', 'rating': '10'}, {'user_id': '204013705', 'rating': '8'}, {'user_id': '124947790', 'rating': '7'}, {'user_id': '158967094', 'rating': '10'}, {'user_id': '22401313', 'rating': '7'}]
# [{'movie_id': '195434', 'rating': '8'}, {'movie_id': '555', 'rating': '6'}, {'movie_id': '615583', 'rating': '6'}, {'movie_id': '1183566', 'rating': '1'}, {'movie_id': '8344', 'rating': '6'}, {'movie_id': '589290', 'rating': '8'}, {'movie_id': '403', 'rating': '8'}]
# Found 4 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Тизер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №2 (дублированный)
# [{'movie_id': '14288', 'rating': '8'}, {'movie_id': '3003', 'rating': '7'}, {'movie_id': '81584', 'rating': '7'}, {'movie_id': '523248', 'rating': '7'}, {'movie_id': '462938', 'rating': '7'}, {'movie_id': '456', 'rating': '8'}, {'movie_id': '575195', 'rating': '7'}, {'movie_id': '682688', 'rating': '7'}, {'movie_id': '102152', 'rating': '7'}, {'movie_id': '1942', 'rating': '7'}]
# Found 10 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер №2
# Parsed new movie: Трейлер №1
# [{'movie_id': '394', 'rating': '9'}, {'movie_id': '1091', 'rating': '9'}, {'movie_id': '102124', 'rating': '9'}, {'movie_id': '195434', 'rating': '8'}, {'movie_id': '5928', 'rating': '7'}, {'movie_id': '350', 'rating': '7'}, {'movie_id': '327', 'rating': '7'}, {'movie_id': '5267432', 'rating': '8'}, {'movie_id': '688', 'rating': '9'}, {'movie_id': '407636', 'rating': '8'}]
# Found 7 new movies to parse
# Parsed new movie: Red-band трейлер (русский язык)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# [{'movie_id': '1114927', 'rating': '7'}, {'movie_id': '195434', 'rating': '6'}, {'movie_id': '23488', 'rating': '8'}, {'movie_id': '1402927', 'rating': '9'}, {'movie_id': '5405057', 'rating': '7'}, {'movie_id': '437410', 'rating': '10'}, {'movie_id': '111543', 'rating': '10'}, {'movie_id': '47237', 'rating': '10'}, {'movie_id': '775273', 'rating': '9'}]
# Found 4 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер №4 (дублированный)
# [{'movie_id': '819101', 'rating': '10'}, {'movie_id': '2494', 'rating': '9'}, {'movie_id': '195434', 'rating': '9'}, {'movie_id': '104938', 'rating': '10'}, {'movie_id': '838', 'rating': '9'}, {'movie_id': '939411', 'rating': '8'}, {'movie_id': '7466', 'rating': '8'}, {'movie_id': '835086', 'rating': '8'}, {'movie_id': '350', 'rating': '10'}, {'movie_id': '43970', 'rating': '7'}]
# Total unique movies: 720
# [{'user_id': '61251957', 'rating': '9'}, {'user_id': '185340658', 'rating': '10'}, {'user_id': '117169593', 'rating': '10'}, {'user_id': '171426451', 'rating': '7'}, {'user_id': '53174505', 'rating': '10'}, {'user_id': '57609729', 'rating': '8'}, {'user_id': '162568279', 'rating': '10'}, {'user_id': '51235659', 'rating': '10'}, {'user_id': '117763754', 'rating': '10'}, {'user_id': '205695256', 'rating': '10'}, {'user_id': '94268808', 'rating': '9'}, {'user_id': '42490020', 'rating': '5'}, {'user_id': '196409390', 'rating': '10'}, {'user_id': '115459977', 'rating': '8'}, {'user_id': '116019425', 'rating': '10'}, {'user_id': '84679788', 'rating': '10'}, {'user_id': '20010981', 'rating': '1'}, {'user_id': '181880389', 'rating': '10'}, {'user_id': '50736777', 'rating': '9'}, {'user_id': '147743507', 'rating': '8'}]
# [{'movie_id': '104938', 'rating': '9'}, {'movie_id': '6282815', 'rating': '9'}]
# Found 1 new movies to parse
# Parsed new movie: Новый сезон на Кинопоиске (2024)18+
# [{'movie_id': '104938', 'rating': '10'}, {'movie_id': '261363', 'rating': '10'}, {'movie_id': '397667', 'rating': '10'}, {'movie_id': '797601', 'rating': '10'}, {'movie_id': '1009713', 'rating': '1'}, {'movie_id': '505811', 'rating': '10'}, {'movie_id': '413447', 'rating': '8'}, {'movie_id': '1338502', 'rating': '10'}]
# Found 5 new movies to parse
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Интернет-трейлер (дублированный)
# [{'movie_id': '819101', 'rating': '10'}, {'movie_id': '2494', 'rating': '9'}, {'movie_id': '195434', 'rating': '9'}, {'movie_id': '104938', 'rating': '10'}, {'movie_id': '838', 'rating': '9'}, {'movie_id': '939411', 'rating': '8'}, {'movie_id': '7466', 'rating': '8'}, {'movie_id': '835086', 'rating': '8'}, {'movie_id': '350', 'rating': '10'}, {'movie_id': '43970', 'rating': '7'}]
# [{'movie_id': '435', 'rating': '8'}, {'movie_id': '803422', 'rating': '5'}, {'movie_id': '586397', 'rating': '7'}, {'movie_id': '841613', 'rating': '10'}, {'movie_id': '462606', 'rating': '6'}, {'movie_id': '786958', 'rating': '8'}, {'movie_id': '635772', 'rating': '9'}, {'movie_id': '522892', 'rating': '9'}, {'movie_id': '77439', 'rating': '4'}]
# Found 4 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Международный трейлер (дублированный)
# Parsed new movie: Трейлер №2 (дублированный)
# [{'movie_id': '104938', 'rating': '10'}, {'movie_id': '1309570', 'rating': '10'}]
# Found 1 new movies to parse
# Parsed new movie: Трейлер (дублированный)
# Total unique movies: 731
# [{'user_id': '204268988', 'rating': '10'}, {'user_id': '117169593', 'rating': '9'}, {'user_id': '110692680', 'rating': '10'}, {'user_id': '106793399', 'rating': '7'}, {'user_id': '153334451', 'rating': '9'}, {'user_id': '202320117', 'rating': '10'}, {'user_id': '13671925', 'rating': '6'}, {'user_id': '199243100', 'rating': '7'}, {'user_id': '103237368', 'rating': '10'}, {'user_id': '11469882', 'rating': '1'}, {'user_id': '76188583', 'rating': '6'}, {'user_id': '182320100', 'rating': '8'}, {'user_id': '152719823', 'rating': '10'}, {'user_id': '114329490', 'rating': '10'}, {'user_id': '52911132', 'rating': '10'}, {'user_id': '16219503', 'rating': '10'}, {'user_id': '150577341', 'rating': '10'}, {'user_id': '23052352', 'rating': '10'}, {'user_id': '184186635', 'rating': '10'}, {'user_id': '41252131', 'rating': '8'}]
# [{'movie_id': '5492', 'rating': '10'}, {'movie_id': '838', 'rating': '10'}, {'movie_id': '395', 'rating': '10'}, {'movie_id': '2717', 'rating': '10'}, {'movie_id': '345', 'rating': '10'}, {'movie_id': '843650', 'rating': '10'}, {'movie_id': '843649', 'rating': '10'}, {'movie_id': '251733', 'rating': '10'}, {'movie_id': '3797', 'rating': '10'}, {'movie_id': '4541', 'rating': '10'}]
# Found 7 new movies to parse
# Parsed new movie: Трейлер
# Parsed new movie: Трейлер (русский язык)
# Parsed new movie: Трейлер №2 (дублированный)
# Parsed new movie: Трейлер 4K-реставрации (русские субтитры)
# Parsed new movie: Интернет-трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)
# Parsed new movie: Трейлер (дублированный)

# %% [markdown]
# ## 1. Popularity-Based Recommendation System
#
# This system recommends movies based on their popularity using weighted ratings, similar to the book recommendation system.

# %%
def create_popularity_recommendations(movies_df, ratings_df):
    """
    Create popularity-based recommendations using weighted ratings
    """
    # Merge movies with ratings
    movie_ratings = ratings_df.merge(movies_df, left_on='movie_id', right_on='id', how='inner')
    
    # Calculate average ratings
    avg_ratings = movie_ratings.groupby('Название')['rating'].mean().reset_index()
    avg_ratings.columns = ['Название', 'avg_rating']
    
    # Calculate rating counts
    cnt_ratings = movie_ratings.groupby('Название')['rating'].count().reset_index()
    cnt_ratings.columns = ['Название', 'count_rating']
    
    # Merge average and count
    popularity = avg_ratings.merge(cnt_ratings, on='Название')
    
    # Calculate weighted score using IMDB formula
    v = popularity['count_rating']
    R = popularity['avg_rating']
    m = v.quantile(0.70)  # Movies must have at least 70th percentile of votes
    c = R.mean()  # Average rating across all movies
    
    # Calculate weighted score
    popularity['w_score'] = ((v * R) + (m * c)) / (v + m)
    
    # Sort by weighted score
    popular_movies = popularity.sort_values('w_score', ascending=False)
    
    return popular_movies

def plot_top_movies(popular_movies, top_n=10):
    """
    Plot top N movies by weighted score
    """
    top_movies = popular_movies.head(top_n)
    
    plt.figure(figsize=(15, 8))
    sns.barplot(data=top_movies, x='w_score', y='Название')
    plt.xlabel('Weighted Score')
    plt.ylabel('Movie Title')
    plt.title(f'Top {top_n} Movies by Weighted Score')
    plt.tight_layout()
    plt.show()
    
    return top_movies

# %% [markdown]
# ## 2. Collaborative Filtering Recommendation System
#
# This system finds similar users or similar movies based on rating patterns.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix

def prepare_collaborative_filtering_data(movies_df, ratings_df, min_ratings=5):
    """
    Prepare data for collaborative filtering
    """
    # Merge ratings with movie titles
    ratings_with_movies = ratings_df.merge(movies_df[['id', 'Название']], 
                                         left_on='movie_id', right_on='id', how='inner')
    
    # Filter users and movies with minimum ratings
    user_counts = ratings_with_movies['user_id'].value_counts()
    movie_counts = ratings_with_movies['Название'].value_counts()
    
    active_users = user_counts[user_counts >= min_ratings].index
    popular_movies = movie_counts[movie_counts >= min_ratings].index
    
    filtered_ratings = ratings_with_movies[
        ratings_with_movies['user_id'].isin(active_users) & 
        ratings_with_movies['Название'].isin(popular_movies)
    ]
    
    # Create user-movie matrix
    user_movie_matrix = filtered_ratings.pivot_table(
        index='user_id', 
        columns='Название', 
        values='rating'
    ).fillna(0)
    
    return user_movie_matrix, filtered_ratings

def find_similar_movies_collaborative(user_movie_matrix, movie_name, num_recommendations=10):
    """
    Find similar movies using collaborative filtering
    """
    if movie_name not in user_movie_matrix.columns:
        return f"Movie '{movie_name}' not found in the dataset"
    
    # Get movie ratings vector
    movie_ratings = user_movie_matrix[movie_name]
    
    # Calculate cosine similarity with all other movies
    movie_matrix = user_movie_matrix.T  # Transpose to get movies as rows
    similarity_scores = cosine_similarity([movie_ratings], movie_matrix.values)[0]
    
    # Create similarity dataframe
    movies_similarity = pd.DataFrame({
        'Название': movie_matrix.index,
        'similarity_score': similarity_scores
    }).sort_values('similarity_score', ascending=False)
    
    # Remove the input movie itself and return top recommendations
    recommendations = movies_similarity[movies_similarity['Название'] != movie_name].head(num_recommendations)
    
    return recommendations

def find_user_recommendations(user_movie_matrix, user_id, num_recommendations=10):
    """
    Find movie recommendations for a specific user
    """
    if user_id not in user_movie_matrix.index:
        return f"User {user_id} not found in the dataset"
    
    # Get user's ratings
    user_ratings = user_movie_matrix.loc[user_id]
    
    # Find movies the user hasn't rated
    unrated_movies = user_ratings[user_ratings == 0].index
    
    if len(unrated_movies) == 0:
        return "User has rated all movies in the dataset"
    
    # Calculate similarity with other users
    user_similarity = cosine_similarity([user_ratings], user_movie_matrix.values)[0]
    
    # Create similarity dataframe
    user_sim_df = pd.DataFrame({
        'user_id': user_movie_matrix.index,
        'similarity': user_similarity
    }).sort_values('similarity', ascending=False)
    
    # Remove the target user
    similar_users = user_sim_df[user_sim_df['user_id'] != user_id].head(10)
    
    # Calculate weighted average ratings for unrated movies
    recommendations = []
    for movie in unrated_movies:
        weighted_sum = 0
        similarity_sum = 0
        
        for _, similar_user in similar_users.iterrows():
            sim_user_id = similar_user['user_id']
            similarity = similar_user['similarity']
            rating = user_movie_matrix.loc[sim_user_id, movie]
            
            if rating > 0:  # Only consider movies rated by similar users
                weighted_sum += similarity * rating
                similarity_sum += similarity
        
        if similarity_sum > 0:
            predicted_rating = weighted_sum / similarity_sum
            recommendations.append({
                'Название': movie,
                'predicted_rating': predicted_rating
            })
    
    # Sort by predicted rating
    recommendations_df = pd.DataFrame(recommendations).sort_values('predicted_rating', ascending=False)
    
    return recommendations_df.head(num_recommendations)

# %% [markdown]
# ## 3. Content-Based Recommendation System
#
# This system recommends movies based on movie features like genre, director, and country.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

def prepare_content_based_data(movies_df):
    """
    Prepare data for content-based recommendations
    """
    # Clean the data
    movies_clean = movies_df.copy()
    movies_clean = movies_clean.fillna('Unknown')
    
    # Create content features by combining genre, director, and country
    movies_clean['content_features'] = (
        movies_clean['Жанр'].astype(str) + ' ' + 
        movies_clean['Режиссёр'].astype(str) + ' ' + 
        movies_clean['Страна'].astype(str)
    )
    
    return movies_clean

def find_similar_movies_content_based(movies_df, movie_name, num_recommendations=10):
    """
    Find similar movies using content-based filtering
    """
    # Prepare data
    movies_clean = prepare_content_based_data(movies_df)
    
    # Check if movie exists
    if movie_name not in movies_clean['Название'].values:
        return f"Movie '{movie_name}' not found in the dataset"
    
    # Create TF-IDF matrix
    tfidf = TfidfVectorizer(stop_words='english', lowercase=True)
    tfidf_matrix = tfidf.fit_transform(movies_clean['content_features'])
    
    # Calculate cosine similarity
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    
    # Get index of the movie
    movie_idx = movies_clean[movies_clean['Название'] == movie_name].index[0]
    
    # Get similarity scores for all movies
    sim_scores = list(enumerate(cosine_sim[movie_idx]))
    
    # Sort movies by similarity score
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get top similar movies (excluding the input movie)
    movie_indices = [i[0] for i in sim_scores[1:num_recommendations+1]]
    
    # Return recommended movies with their features
    recommendations = movies_clean.iloc[movie_indices][['Название', 'Год', 'Жанр', 'Режиссёр', 'Страна', 'Рейтинг']]
    
    # Add similarity scores
    similarity_scores = [i[1] for i in sim_scores[1:num_recommendations+1]]
    recommendations = recommendations.copy()
    recommendations['similarity_score'] = similarity_scores
    
    return recommendations

def recommend_by_genre(movies_df, genre, num_recommendations=10):
    """
    Recommend top movies from a specific genre
    """
    # Filter movies by genre
    genre_movies = movies_df[movies_df['Жанр'].str.contains(genre, case=False, na=False)]
    
    if genre_movies.empty:
        return f"No movies found for genre '{genre}'"
    
    # Convert rating to numeric and sort
    genre_movies = genre_movies.copy()
    genre_movies['Рейтинг_numeric'] = pd.to_numeric(genre_movies['Рейтинг'], errors='coerce')
    
    # Sort by rating and return top recommendations
    top_movies = genre_movies.sort_values('Рейтинг_numeric', ascending=False).head(num_recommendations)
    
    return top_movies[['Название', 'Год', 'Жанр', 'Режиссёр', 'Страна', 'Рейтинг']]

# %% [markdown]
# ## 4. Complete Recommendation System Implementation
#
# Now let's create a comprehensive function that combines all recommendation methods.

# %%
class MovieRecommendationSystem:
    def __init__(self, movies_df, ratings_df):
        self.movies_df = movies_df
        self.ratings_df = ratings_df
        self.user_movie_matrix = None
        self.popular_movies = None
        self.setup_system()
    
    def setup_system(self):
        """Initialize all recommendation components"""
        # Prepare popularity-based recommendations
        self.popular_movies = create_popularity_recommendations(self.movies_df, self.ratings_df)
        
        # Prepare collaborative filtering data
        if not self.ratings_df.empty:
            try:
                self.user_movie_matrix, _ = prepare_collaborative_filtering_data(
                    self.movies_df, self.ratings_df, min_ratings=3
                )
            except Exception as e:
                print(f"Could not prepare collaborative filtering: {e}")
                self.user_movie_matrix = None
    
    def get_popular_movies(self, n=10):
        """Get top popular movies"""
        return self.popular_movies.head(n)
    
    def get_similar_movies(self, movie_name, method='content', n=10):
        """Get similar movies using specified method"""
        if method == 'content':
            return find_similar_movies_content_based(self.movies_df, movie_name, n)
        elif method == 'collaborative' and self.user_movie_matrix is not None:
            return find_similar_movies_collaborative(self.user_movie_matrix, movie_name, n)
        else:
            return "Collaborative filtering not available or method not recognized"
    
    def get_user_recommendations(self, user_id, n=10):
        """Get recommendations for a specific user"""
        if self.user_movie_matrix is not None:
            return find_user_recommendations(self.user_movie_matrix, user_id, n)
        else:
            return "Collaborative filtering not available"
    
    def get_genre_recommendations(self, genre, n=10):
        """Get top movies from a specific genre"""
        return recommend_by_genre(self.movies_df, genre, n)
    
    def get_comprehensive_recommendations(self, movie_name=None, user_id=None, genre=None, n=5):
        """Get comprehensive recommendations using multiple methods"""
        recommendations = {}
        
        # Popular movies
        recommendations['popular'] = self.get_popular_movies(n)
        
        # Movie-based recommendations
        if movie_name:
            recommendations['similar_content'] = self.get_similar_movies(movie_name, 'content', n)
            if self.user_movie_matrix is not None:
                recommendations['similar_collaborative'] = self.get_similar_movies(movie_name, 'collaborative', n)
        
        # User-based recommendations
        if user_id:
            recommendations['user_based'] = self.get_user_recommendations(user_id, n)
        
        # Genre-based recommendations
        if genre:
            recommendations['genre_based'] = self.get_genre_recommendations(genre, n)
        
        return recommendations
